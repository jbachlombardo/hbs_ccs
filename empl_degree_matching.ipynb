# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
current_empl_17 = pd.read_csv('C:/Users/jbachlombardo/Documents/Community Colleges/Data/College scorecard/CollegeScorecard_Raw_Data/agged_empl_wages_by_county.csv')

# %%
current_empl_17_fourdigi = pd.read_csv('C:/Users/jbachlombardo/Documents/Community Colleges/Data/College scorecard/CollegeScorecard_Raw_Data/agged_empl_wages_by_county_FOUR DIGITS.csv')

# %%
current_school_degrees = pd.read_csv('C:/Users/jbachlombardo/Documents/Community Colleges/Data/College scorecard/CollegeScorecard_Raw_Data/merged_all_scorecard_indicators_longitudinal_zips_RESET FROM HERE 42919_adjacents.csv')

# %%
current_school_degrees = current_school_degrees.drop('Unnamed: 0', axis = 1)
current_empl_17 = current_empl_17.drop('Unnamed: 0', axis = 1)

# %%
deg_ind_cross = pd.read_csv('C:/Users/jbachlombardo/Documents/Community Colleges/Data/CIP NAICS Crosswalk.csv')

# %%
pivoted_current_empl_17 = pd.pivot_table(current_empl_17, columns = 'industry_code', index = ['FIPS', 'County_State'], values = ['annual_avg_emplvl', 'total_annual_wages', 'annual_avg_wkly_wage'])

# %%
pivoted_current_empl_17.columns = [a + '_' + b for a, b in pivoted_current_empl_17.columns]

# %%
pivoted_current_empl_17.to_csv('C:/Users/jbachlombardo/Documents/Community Colleges/Data/College scorecard/CollegeScorecard_Raw_Data/pivoted_agged_empl_wages_by_county.csv')

# %%
pivoted_current_empl_17['total_annual_avg_emplvl'] = pivoted_current_empl_17[pivoted_current_empl_17.columns[pivoted_current_empl_17.columns.str.contains('avg_emplvl')]].sum(axis = 1)

# %%
for c in pivoted_current_empl_17.columns[pivoted_current_empl_17.columns.str.contains('avg_emplvl')][:-1] :
    newcol = c + '_%'
    pivoted_current_empl_17[newcol] = pivoted_current_empl_17[c] / pivoted_current_empl_17['total_annual_avg_emplvl']

# %%
#current_empl_17_fourdigi.groupby('industry_code')['annual_avg_emplvl'].sum().sort_values(ascending = False)
current_empl_17_fourdigi
# Out:
#         Unnamed: 0 industry_code  annual_avg_emplvl  total_annual_wages  \
# 0                0          1133                  6              206363
# 1                1          1151                  0                   0
# 2                2          1152                  0                   0
# 3                3          2111                  0                   0
# 4                4          2123                 41             1876333
# 5                5          2131                  0                   0
# 6                6          2211                240            13164877
# 7                7          2212                  0                   0
# 8                8          2213                131             5878519
# 9                9          2361                624            39006996
# 10              10          2362                277            15666437
# 11              11          2371                185             8189290
# ...
